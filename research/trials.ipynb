# %%
import os

# %%
# %pwd
# Out:
# 'd:\\PythonStruggle\\MachineLearning\\text-summarization-system\\research'

# %%
os.chdir('../')

# %%
# %pwd
# Out:
# 'd:\\PythonStruggle\\MachineLearning\\text-summarization-system'
